# %%
# !pip install torch
# !pip install torchvision
# Out:
# Requirement already satisfied: torch in d:\python\python313\lib\site-packages (2.8.0)
# Requirement already satisfied: filelock in d:\python\python313\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\python\python313\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in d:\python\python313\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in d:\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in d:\python\python313\lib\site-packages (from torch) (2025.7.0)
# Requirement already satisfied: setuptools in d:\python\python313\lib\site-packages (from torch) (76.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python\python313\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in d:\python\python313\lib\site-packages (from torchvision) (2.2.3)
# Requirement already satisfied: torch==2.8.0 in d:\python\python313\lib\site-packages (from torchvision) (2.8.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\python\python313\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (2025.7.0)
# Requirement already satisfied: setuptools in d:\python\python313\lib\site-packages (from torch==2.8.0->torchvision) (76.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\python\python313\lib\site-packages (from sympy>=1.13.3->torch==2.8.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python\python313\lib\site-packages (from jinja2->torch==2.8.0->torchvision) (3.0.2)
# Downloading torchvision-0.23.0-cp313-cp313-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 9.8 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.23.0
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import random

# %%
transform = transforms.ToTensor()

train_set = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_set = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1000, shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)   # flatten
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

model = SimpleNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 5
train_losses, test_accuracies = [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    
    train_losses.append(running_loss / len(train_loader))
    
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    test_accuracies.append(accuracy)
    
    print(f"Epoch {epoch+1}/{epochs}, Loss: {train_losses[-1]:.4f}, Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/5, Loss: 0.3496, Accuracy: 94.91%
# Epoch 2/5, Loss: 0.1417, Accuracy: 96.39%
# Epoch 3/5, Loss: 0.0965, Accuracy: 97.03%
# Epoch 4/5, Loss: 0.0728, Accuracy: 97.00%
# Epoch 5/5, Loss: 0.0585, Accuracy: 97.44%

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(train_losses, label="Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(test_accuracies, label="Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.show()

# %%
model.eval()
fig, axes = plt.subplots(2, 5, figsize=(10,5))
for i in range(10):
    idx = random.randint(0, len(test_set)-1)
    image, label = test_set[idx]
    output = model(image.unsqueeze(0))
    _, pred = torch.max(output, 1)
    
    ax = axes[i//5, i%5]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(f"T:{label}, P:{pred.item()}")
    ax.axis("off")

plt.show()
