# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from collections import Counter
from sklearn.covariance import EllipticEnvelope

# %%
df = pd.read_csv('creditcard.csv').drop(['Time'], axis=1)

# %%
df.drop_duplicates().Class.value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
# 5  0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398 -0.371427
# 6  0.081213  0.464960 -0.099254  ... -0.167716 -0.270710 -0.154104 -0.780055
# 7 -3.807864  0.615375  1.249376  ...  1.943465 -1.015455  0.057504 -0.649709
# 8  0.851084 -0.392048 -0.410430  ... -0.073425 -0.268092 -0.204233  1.011592
# 9  0.069539 -0.736727 -0.366846  ... -0.246914 -0.633753 -0.120794 -0.385050
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
# 5 -0.232794  0.105915  0.253844  0.081080    3.67      0
# 6  0.750137 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.415267 -0.051634 -1.206921 -1.085339   40.80      0
# 8  0.373205 -0.384157  0.011747  0.142404   93.20      0
# 9 -0.069733  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      284807 non-null  float64
#  1   V2      284807 non-null  float64
#  2   V3      284807 non-null  float64
#  3   V4      284807 non-null  float64
#  4   V5      284807 non-null  float64
#  5   V6      284807 non-null  float64
#  6   V7      284807 non-null  float64
#  7   V8      284807 non-null  float64
#  8   V9      284807 non-null  float64
#  9   V10     284807 non-null  float64
#  10  V11     284807 non-null  float64
#  11  V12     284807 non-null  float64
#  12  V13     284807 non-null  float64
#  13  V14     284807 non-null  float64
#  14  V15     284807 non-null  float64
#  15  V16     284807 non-null  float64
#  16  V17     284807 non-null  float64
#  17  V18     284807 non-null  float64
#  18  V19     284807 non-null  float64
#  19  V20     284807 non-null  float64
#  20  V21     284807 non-null  float64
#  21  V22     284807 non-null  float64
#  22  V23     284807 non-null  float64
#  23  V24     284807 non-null  float64
#  24  V25     284807 non-null  float64
#  25  V26     284807 non-null  float64
#  26  V27     284807 non-null  float64
#  27  V28     284807 non-null  float64
#  28  Amount  284807 non-null  float64
#  29  Class   284807 non-null  int64
# dtypes: float64(29), int64(1)
# memory usage: 65.2 MB

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X = df.drop(columns=['Class'])
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,
    random_state=42
)

clf = RandomForestClassifier(
    n_estimators=100,
    n_jobs=-1,
    random_state=42,
    class_weight='balanced'
)
clf.fit(X_train, y_train)

importances = clf.feature_importances_
feat_imp = pd.DataFrame({
    'feature': X.columns,
    'importance': importances
})
feat_imp = feat_imp.sort_values('importance', ascending=False).reset_index(drop=True)

print(feat_imp)

plt.figure(figsize=(8, 10))
plt.barh(feat_imp['feature'], feat_imp['importance'])
plt.gca().invert_yaxis()
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.tight_layout()
plt.show()
# Out:
#    feature  importance
# 0      V10    0.154809
# 1      V14    0.139288
# 2       V4    0.128538
# 3      V12    0.102290
# 4      V11    0.086573
# 5      V17    0.073107
# 6       V3    0.053273
# 7       V7    0.046660
# 8      V16    0.038420
# 9       V2    0.019026
# 10     V21    0.018972
# 11      V9    0.011651
# 12     V19    0.010332
# 13  Amount    0.009658
# 14     V18    0.009561
# 15     V28    0.009482
# 16     V20    0.009241
# 17      V6    0.008451
# 18     V26    0.007858
# 19     V13    0.007664
# 20     V27    0.007551
# 21      V5    0.007115
# 22     V15    0.006927
# 23      V8    0.006737
# 24     V25    0.005903
# 25     V22    0.005713
# 26      V1    0.005487
# 27     V24    0.005262
# 28     V23    0.004450

# %%
features = ['V10','V14','V4','V12', 'V11', 'V17', 'Class']

# %%
df = df[features].copy(deep=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V10     284807 non-null  float64
#  1   V14     284807 non-null  float64
#  2   V4      284807 non-null  float64
#  3   V12     284807 non-null  float64
#  4   V11     284807 non-null  float64
#  5   V17     284807 non-null  float64
#  6   Class   284807 non-null  int64
# dtypes: float64(6), int64(1)
# memory usage: 15.2 MB

# %%
fig, axes = plt.subplots(3,2, figsize=(17, 12))
fig.suptitle('Features vs Class', size=18)

for ax, feat in zip(axes.flatten(), features):
    sns.boxplot(
        ax=ax,
        data=df,
        x='Class',
        y=feat,
        hue='Class',
        palette='Spectral',
        dodge=False
    )
    ax.set_title(f"{feat} distribution")
    ax.get_legend().remove()

plt.tight_layout(rect=[0, 0, 1, 0.96])

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(13, 8))
fig.suptitle('Distributions\n', size=18)

for ax, feat in zip(axes.flatten(), features):
    ax.hist(df[feat], bins=60, linewidth=0.5, edgecolor='white')
    ax.set_title(f"{feat} distribution")

plt.tight_layout()

# %%
features = ['V10','V14','V4','V12', 'V11','V17']

sns.pairplot(df[features], diag_kind='hist', plot_kws={'alpha':0.4, 's':20})
plt.suptitle('Pairwise Scatterplots', y=1.02)
plt.show()

# %%
from sklearn.covariance import EllipticEnvelope

# %%
algorithm = EllipticEnvelope(random_state=2021).fit(df)
y_pred = algorithm.predict(df)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(284807,))

# %%
plt.figure(figsize=(5, 5))
colors = np.array(['#377eb8', '#ff7f00'])
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], s=40, color=colors[(y_pred - 1) // 2])

# %%
plt.figure(figsize=(10, 10))

outliers_fraction = [.007, .01, .02, .03, .05, .1]
for i, of in enumerate(outliers_fraction):
    ax = plt.subplot(2, 3, i + 1)

    algorithm = EllipticEnvelope(contamination=of, random_state=2021).fit(X)
    y_pred = algorithm.predict(X)

    ax.scatter(df.iloc[:, 0], df.iloc[:, 1], s=40, color=colors[(y_pred - 1) // 2])
# Out:
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.902917813001551 > -299.447213511486495). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-251.582170242525279 > -268.523931518193137). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-247.284642613643427 > -266.482846902204699). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-210.802037251719440 > -295.644574293871017). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.581373297702555 > -269.550721302145291). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-159.755601012046498 > -260.343339888061280). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.116498956866877 > -237.510741508980345). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-271.446031651180760 > -272.106166430817495). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.116498956866877 > -241.901431558620601). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-181.674237546361269 > -265.643218290874870). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.750440596483372 > -238.058365173766333). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.690989772185532 > -236.495016348055458). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-186.210678909111806 > -238.963059021253514). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-177.654232456640074 > -233.786315479927936). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-253.096955735389713 > -268.830210634072785). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-176.564520988100838 > -237.798955443412808). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-214.101927335215692 > -214.306654134655474). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-224.186479101642306 > -304.285966047532838). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-182.106380496215507 > -236.639152409207725). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-211.502880608192555 > -240.329658061518444). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-190.899206016468156 > -192.392308976797665). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-173.190131247210843 > -176.086626364408943). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-244.116858741216220 > -269.824331267386924). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-238.062849805493016 > -266.562532819337889). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-225.099526804137440 > -300.751729111627014). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-228.828857382920290 > -301.925151559171240). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.059460317316280 > -256.096568608565121). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-247.316281457329040 > -250.178642652881905). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.061117456180767 > -239.428115937039422). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.536456505542134 > -265.521563953904888). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-162.055294087749104 > -164.371692575433144). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-184.581414410300141 > -185.600082299593396). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.371291419135645 > -270.281457677970707). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-187.735257759789619 > -188.419103700071361). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.091278165671156 > -298.699068644035947). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-249.108501462973351 > -267.993279737848525). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-273.122826439440701 > -274.088801724882273). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-192.250867458986193 > -192.903140474097626). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-243.879124301589712 > -270.445010267231623). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-241.551240139996878 > -304.882520505998968). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.220310426721738 > -239.778200510291128). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-183.904523546545562 > -237.509734201961351). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-276.502771891588282 > -276.657548001576970). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-242.933232916537264 > -301.893059836837608). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.032427629123106 > -264.710399082482468). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-179.751088489711748 > -263.154033501454762). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.619841763785729 > -235.780688413427470). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-226.353895892633460 > -304.240250116542086). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-210.095832538487628 > -240.175615603836377). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.945989743376657 > -266.434177359224748). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-203.838391606699275 > -238.510787250573230). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-105.859310767605223 > -288.352691894645204). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.171068920651464 > -237.182722891595915). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-245.162150196641221 > -267.396037255403826). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-237.521405475682940 > -237.578920001169564). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.549745967945341 > -241.259832463875796). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-181.728331594384940 > -183.801694723473474). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-177.697050834899329 > -182.232329419764966). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-153.469730972140127 > -153.488216123105985). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-229.580443118185144 > -232.376877517354302). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-182.875411270608822 > -236.677015447956791). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-227.571410469709946 > -299.276261998142672). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-240.150529302125250 > -240.398925561068154). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-238.581989110076535 > -265.344230669098010). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-188.954581471339509 > -189.145112214025204). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-213.652422656697070 > -291.556070840268490). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.893763913251661 > -265.154873017503860). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.366962900525948 > -239.267136773060940). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-211.848977788332149 > -266.723996120668858). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-202.099436988227524 > -233.117224071275473). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-238.711181649644175 > -294.227981976737510). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-269.494517621686498 > -271.639729826289056). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-221.035670783258894 > -301.294004083664163). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-178.464792204863357 > -238.428848065394789). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-270.754232037311908 > -275.756374349433599). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.139774258264453 > -236.807204248372472). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-230.712620721867040 > -235.577892756090364). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-227.606518688562176 > -299.764175568977976). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-259.849106171677988 > -263.988761306132119). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.922855328630448 > -236.941330862004634). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-216.576909264901104 > -269.244492701661102). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-176.108598927255514 > -238.736596887860998). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-272.456057064405854 > -272.685989597431444). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-212.790236917883931 > -270.033057814086817). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-180.824067344128281 > -182.680477580399184). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-231.651301548591704 > -296.740155446483243). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-91.417569016815762 > -294.429936706152205). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-200.695581965653787 > -294.499295863090765). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-242.626621368704178 > -268.302973253998175). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-150.532360680816367 > -264.374193667922952). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.001422841317321 > -263.449895029255799). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-244.729457632410345 > -301.258566347085321). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-185.370403665243799 > -235.533510932088632). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-195.536612872496335 > -291.534786826647576). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-210.832055752418285 > -291.957233490343583). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.411862774960440 > -238.467039390774715). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-179.137612141533367 > -179.577319781206540). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-178.464792204863357 > -237.932465851588148). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-224.677078873519775 > -300.157419827616309). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-151.901772164102653 > -264.410364861612095). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-237.322856408428208 > -280.365646111728836). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-222.256766956376765 > -301.275084163537258). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.146086739117720 > -177.825475016138881). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-204.896210536554037 > -270.795935435543186). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.511769041053782 > -237.790740975369317). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.715492708466570 > -239.747161460355414). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-177.901633491340192 > -180.162245095827558). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-230.556198260388015 > -238.648213064263416). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-247.573291760474149 > -266.885257844913610). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-100.802673269676475 > -293.448315396279668). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-204.813166339661535 > -237.773115240744488). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-183.935631924022829 > -230.811978596043161). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-92.576782223141038 > -295.443610120668268). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.396092229620734 > -236.652398010176114). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.075032815391125 > -294.818868162160641). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-227.733872914745348 > -300.104977099022392). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-244.135792920677716 > -245.894856697054195). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-204.280585985808358 > -300.638159674531266). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.362646353508950 > -237.401432981341571). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-202.645117062454290 > -268.492579011512419). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-181.492135206464269 > -249.606901887238621). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.330451618855847 > -239.058302205049671). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-181.523800640149574 > -230.607012856894841). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-204.536515833328849 > -237.782942251448503). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-214.064016254751294 > -276.901130088546779). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.190057198485022 > -298.285755891961458). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.308108970843278 > -241.165435777820790). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-206.311952522897656 > -239.185184281758438). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-227.537434189932497 > -233.440856992768033). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.153156905066368 > -261.994530970463074). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-244.388221319309736 > -267.742049209868526). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-183.389979658610997 > -290.538246697537545). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-252.713570715719129 > -261.604039349450659). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-181.274897723601100 > -262.969865544423101). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-223.547313819853741 > -303.167152197057362). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.247600452690051 > -156.328522161045669). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.757044401315341 > -236.241384405662927). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-252.447556727178750 > -271.667949504677892). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.836291799476243 > -235.449657397776548). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-179.785067577554798 > -235.248976585142401). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-101.179801084557383 > -293.842316163055557). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.006651061027924 > -237.480091861385517). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-188.765167681549173 > -238.892712891430165). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-159.718219760552586 > -230.911506022306668). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.802904715505548 > -264.621496581459269). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-191.829296740229267 > -192.815364777367762). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# ...
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-252.713570715719129 > -261.604039349450659). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-181.274897723601100 > -262.969865544423101). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-223.547313819853741 > -303.167152197057362). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.247600452690051 > -156.328522161045669). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.757044401315341 > -236.241384405662927). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-252.447556727178750 > -271.667949504677892). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.836291799476243 > -235.449657397776548). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-179.785067577554798 > -235.248976585142401). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-101.179801084557383 > -293.842316163055557). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.006651061027924 > -237.480091861385517). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-188.765167681549173 > -238.892712891430165). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-159.718219760552586 > -230.911506022306668). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-207.802904715505548 > -264.621496581459269). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-191.829296740229267 > -192.815364777367762). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-92.643537978921387 > -293.519824759310382). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-178.332499874175426 > -180.230023479740396). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-213.994274046697001 > -266.967154457582240). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-144.947169501519340 > -145.011957408960939). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-182.092153702022244 > -238.225488708625903). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-188.106163875278497 > -299.433686625376708). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-92.319342309665885 > -292.110232537239426). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-174.107205689512739 > -174.582549334052629). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.546527080062305 > -238.717982879306874). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-228.203032965537687 > -300.597912098327868). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-151.775060308476327 > -262.179835989925323). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-92.218505729189317 > -290.727467496696306). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-209.573574419446800 > -238.325696152991014). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-185.664434410309298 > -235.985704401417195). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-238.816523398255356 > -265.147777818293321). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-251.582170242525279 > -268.954083792024221). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-223.195972131778717 > -305.947510905551553). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-242.646239760212353 > -243.215418991949690). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-236.612743934480932 > -264.156520264347989). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-204.390497199933350 > -237.570829108357373). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-156.763955231153830 > -265.313028127525342). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-244.556159487514122 > -244.751431292239431). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-176.564520988100838 > -235.412968917786145). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-250.427755083748139 > -265.764843800738618). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-205.794289764519192 > -266.796254783633231). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-184.655726763825726 > -241.245632562102003). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-242.967034291309290 > -243.176734987473367). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-232.495122349762966 > -295.825936626857015). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-204.401742408815551 > -236.256250541250267). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-208.354174259951776 > -237.319231812459321). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-238.744820479784835 > -261.937636811220329). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-175.509975900963212 > -264.157323705984368). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-244.113247993791418 > -247.712358344424075). You may want to try with a higher value of support_fraction (current value: 0.501).
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\covariance\_robust_covariance.py:185: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-103.688894906732628 > -228.683964718192840). You may want to try with a higher value of support_fraction (current value: 0.500).
#   warnings.warn(

# %%
import time

from sklearn import svm
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.kernel_approximation import Nystroem
from sklearn.linear_model import SGDOneClassSVM
from sklearn.neighbors import LocalOutlierFactor
from sklearn.pipeline import make_pipeline

# %%
n_samples = len(df)
outliers_fraction = len(df[df['Class'] == 1])/float(len(df[df['Class'] == 0]))
n_outliers = int(outliers_fraction * n_samples)
n_inliers = n_samples - n_outliers

# %%
anomaly_algorithms = [
    (
        "Robust covariance",
        EllipticEnvelope(contamination=outliers_fraction, random_state=42),
    ),
    ("One-Class SVM", svm.OneClassSVM(nu=outliers_fraction, kernel="rbf", gamma=0.1)),
    (
        "One-Class SVM (SGD)",
        make_pipeline(
            Nystroem(gamma=0.1, random_state=42, n_components=150),
            SGDOneClassSVM(
                nu=outliers_fraction,
                shuffle=True,
                fit_intercept=True,
                random_state=42,
                tol=1e-6,
            ),
        ),
    ),
    (
        "Isolation Forest",
        IsolationForest(contamination=outliers_fraction, random_state=42),
    ),
    (
        "Local Outlier Factor",
        LocalOutlierFactor(n_neighbors=35, contamination=outliers_fraction),
    ),
]

# %%
#from sklearn.preprocessing import StandardScaler

#X = df.drop('Class', axis=1).values
#y_true = df['Class'].values

#scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)

# %%
#datasets = [X_scaled]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(df.drop('Class', axis=1).values)  

datasets = [X_pca]

# %%
rng = np.random.RandomState(42)

_, subaxes = plt.subplots(1, 5, figsize=(14, 4))
# plt.subplots_adjust(left=.02, right=.98, bottom=.001, top=.96, wspace=.05,hspace=.01)
plt.subplots_adjust(left=.02, right=.98, wspace=.1)
for ax, X in zip(subaxes, datasets):
    outliers = rng.uniform(low=-6, high=6, size=(n_outliers, 2))
    ax.scatter(X[:, 0], X[:, 1])
    ax.scatter(outliers[:, 0], outliers[:, 1])

# %%
xx, yy = np.meshgrid(np.linspace(-7, 7, 150), np.linspace(-7, 7, 150))

plt.figure(figsize=(len(anomaly_algorithms) * 2 + 4, 12.5))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.96, wspace=0.05, hspace=0.01
)

plot_num = 1
rng = np.random.RandomState(42)

for i_dataset, X in enumerate(datasets):
    # Add outliers
    X = np.concatenate([X, rng.uniform(low=-6, high=6, size=(n_outliers, 2))], axis=0)

    for name, algorithm in anomaly_algorithms:
        t0 = time.time()
        algorithm.fit(X)
        t1 = time.time()
        plt.subplot(len(datasets), len(anomaly_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        # fit the data and tag outliers
        if name == "Local Outlier Factor":
            y_pred = algorithm.fit_predict(X)
        else:
            y_pred = algorithm.fit(X).predict(X)

        # plot the levels lines and the points
        if name != "Local Outlier Factor":  # LOF does not implement predict
            Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])
            Z = Z.reshape(xx.shape)
            plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors="black")

        colors = np.array(["#ff7f00", "#377eb8"])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[(y_pred + 1) // 2])

        plt.xlim(-7, 7)
        plt.ylim(-7, 7)
        plt.xticks(())
        plt.yticks(())
        plt.text(
            0.99,
            0.01,
            ("%.2fs" % (t1 - t0)).lstrip("0"),
            transform=plt.gca().transAxes,
            size=15,
            horizontalalignment="right",
        )
        plot_num += 1

plt.show()
# Out:
# D:\Python\Python313\Lib\site-packages\sklearn\neighbors\_lof.py:322: UserWarning: Duplicate values are leading to incorrect results. Increase the number of neighbors for more accurate results.
#   warnings.warn(
# D:\Python\Python313\Lib\site-packages\sklearn\neighbors\_lof.py:322: UserWarning: Duplicate values are leading to incorrect results. Increase the number of neighbors for more accurate results.
#   warnings.warn(
